# %%
import os
import numpy as np
from matplotlib.image import imread, imsave
from matplotlib import pyplot as plt 

import tensorflow as tf
import tensorflow.keras as keras

# %%
class data_generator:
    dir_name=None
    fileNames=None
    count=None
    n_files=None
    def __init__(self,dir_name):
        self.dir_name=dir_name
        self.fileNames=[x for x in os.listdir(self.dir_name) if x.endswith('.jpg')]
        self.count=0
        self.n_files=len(self.fileNames)

    def getRandomOne(self):
        res=[]
        img=imread(self.dir_name+self.fileNames[np.random.randint(self.n_files)])
        res.append(img/255.0)
        return np.array(res)
    
    def getEpochData(self,size):
        print("Reading Image Bank size:",size)
        res=[]
        for i in range(size):
            img=imread(self.dir_name+self.fileNames[self.count])
            self.count=(self.count+1)%self.n_files
            res.append(img/255.)
        res=np.array(res)
        print("Read Image Bank:",res.shape)
        return res

# %%
class tsop:
    def conv2d(x,n_filters,fsize,strides=1,padding='REFLECT',activation=tf.nn.relu,
               dilation_rate=1,name=None):
        p=dilation_rate*(fsize//2)
        if padding=='REFLECT':
            x=tf.pad(x,[[0,0],[p,p],[p,p],[0,0]],mode=padding,name=name+'_padding')
            padding='VALID'
        x=keras.layers.Conv2D(n_filters,kernel_size=fsize,strides=strides,activation=activation,
                              dilation_rate=dilation_rate,name=name+'_conv',padding=padding)(x)
        return x
    def getMask_256(X):
        m,h,w,c=X.shape
        # (x,y) is the center of mask. x, y is in (64,192)
        x=int(np.random.random()*128+64)
        y=int(np.random.random()*128+64)
        # k is the size of mask, in (96,128)
        k=int(np.random.random()*32+96)
        #image mask denotes inpainting part where it is 1
        image_mask=np.zeros((m,h,w,1))
        image_mask[:,x-64:x+64,y-64:y+64,:]=1 #changed to be same as local mask
        #local mask denotes the part as the input of local discriminator
        local_mask=np.zeros((m,h,w,1))
        local_mask[:,x-64:x+64,y-64:y+64,:]=1
        
        return image_mask,local_mask

# %%
def generator(x: tf.Tensor,mask: tf.Tensor):
    g_vars=[t for t in tf.global_variables() if t.name.startswith('generator')]
    with tf.variable_scope('generator',reuse=len(g_vars)>0):
        m,h,w,c=x.shape.as_list()
        inpainting_mask=tf.broadcast_to(mask,[m,h,w,c])
        denoting_mask=tf.broadcast_to(mask,[m,h,w,1])
        input_images=x
        x=x*(1-inpainting_mask)
        x=tf.concat((x,denoting_mask),axis=-1)
        
        x=tsop.conv2d(x,64,fsize=5,name='step0_0')

        x=tsop.conv2d(x,128,fsize=3,strides=2,name='step1_0')
        x=tsop.conv2d(x,128,fsize=3,name='step1_1')

        x=tsop.conv2d(x,256,fsize=3,strides=2,name='step2_0')
        x=tsop.conv2d(x,256,fsize=3,name='step2_1')
        x=tsop.conv2d(x,256,fsize=3,name='step2_2')
        
        x=tsop.conv2d(x,256,fsize=3,dilation_rate=2,name='step3_0')
        x=tsop.conv2d(x,256,fsize=3,dilation_rate=4,name='step3_1')
        x=tsop.conv2d(x,256,fsize=3,dilation_rate=8,name='step3_2')
        x=tsop.conv2d(x,256,fsize=3,dilation_rate=16,name='step3_3')
        
        x=tsop.conv2d(x,256,fsize=3,name='step4_0')
        x=tsop.conv2d(x,256,fsize=3,name='step4_1')
        
        x=keras.layers.Conv2DTranspose(128,kernel_size=4,strides=2,padding='same',name='step5_0_deconv1')(x)
        x=tsop.conv2d(x,128,fsize=3,name='step5_1')
        
        x=keras.layers.Conv2DTranspose(64,kernel_size=4,strides=2,padding='same',name='step6_0_deconv2')(x)
        x=tsop.conv2d(x,32,fsize=3,name='step6_1')
        x=tsop.conv2d(x,3,fsize=3,name='step6_2',activation=tf.nn.sigmoid)
        res=input_images*(1-inpainting_mask)+x*inpainting_mask
    return res

def global_discriminator(x):
    gd_vars=[t for t in tf.global_variables() if t.name.startswith('global_discriminator')]
    with tf.variable_scope('global_discriminator',reuse=len(gd_vars)>0):
        x=tsop.conv2d(x,64,fsize=5,strides=2,name='step1')
        x=tsop.conv2d(x,128,fsize=5,strides=2,name='step2')
        x=tsop.conv2d(x,256,fsize=5,strides=2,name='step3')
        x=tsop.conv2d(x,512,fsize=5,strides=2,name='step4')
        x=tsop.conv2d(x,512,fsize=5,strides=2,name='step5')
        x=tsop.conv2d(x,512,fsize=5,strides=2,name='step6')
        x=keras.layers.Flatten()(x)
        x=keras.layers.Dense(1)(x)
    return x

def local_discriminator(x,mask):
    
    ld_vars=[t for t in tf.global_variables() if t.name.startswith('local_discriminator')]
    with tf.variable_scope('local_discriminator',reuse=len(ld_vars)>0):
        m,w,h,c=x.shape.as_list()
        mask=tf.broadcast_to(mask,[m,w,h,c])
        win=tf.reshape(tf.boolean_mask(x,mask),shape=(m,128,128,c))
        x=tsop.conv2d(win,64,fsize=5,strides=2,name='step1')
        x=tsop.conv2d(x,128,fsize=5,strides=2,name='step2')
        x=tsop.conv2d(x,256,fsize=5,strides=2,name='step3')
        x=tsop.conv2d(x,512,fsize=5,strides=2,name='step4')
        x=tsop.conv2d(x,512,fsize=5,strides=2,name='step5')
        x=keras.layers.Flatten()(x)
        x=keras.layers.Dense(1)(x)
    return x

def getInterpSample(original_images,generated_images):
    with tf.variable_scope('getInterpSample'):
        m,h,w,c=original_images.shape.as_list() 

        shape=original_images.shape.as_list()
        original_images_vector=tf.reshape(original_images,(-1,h*w*c))
        generated_images_vector=tf.reshape(generated_images,(-1,h*w*c))

        eps=tf.random_uniform([m,1],minval=0.,maxval=1.)
        interp=tf.reshape(eps*original_images_vector+(1-eps)*generated_images_vector,shape)
    return interp

def getGradientPenalty(out_local,out_global,interp,inpainting_mask):
    with tf.variable_scope('getGradientPenalty'):
        mask=tf.broadcast_to(inpainting_mask,interp.shape.as_list())
        gradient_local=tf.multiply(tf.gradients(out_local,interp)[0],mask)
        gradient_global=tf.multiply(tf.gradients(out_global,interp)[0],mask)
        slope_local=tf.sqrt(tf.reduce_sum(tf.square(gradient_local),axis=[1,2,3]))
        slope_global=tf.sqrt(tf.reduce_sum(tf.square(gradient_global),axis=[1,2,3]))
        penalty_local=tf.reduce_mean(tf.nn.relu(slope_local-1))
        penalty_global=tf.reduce_mean(tf.nn.relu(slope_global-1))
    return penalty_local,penalty_global

# %%
class GAN:
    
    def __init__(self):
        self.data=data_generator("training_data/")
        self.total_epoches=1000
        self.batch_size=32
        self.N_each_epoch=960
    
    def build_net_architecture(self):
        #shape=[self.batch_size,256,256,3]
        tf.reset_default_graph()
        original_images=tf.get_variable(name="original_images",dtype=tf.float32,shape=[self.batch_size,256,256,3])
        images_mask=tf.get_variable(name="images_mask",dtype=tf.float32,shape=[self.batch_size,256,256,1])
        localD_mask=tf.get_variable(name="localD_mask",dtype=tf.float32,shape=[self.batch_size,256,256,1])
        
        generated_images=generator(original_images,images_mask)
        
        global_D_pos=global_discriminator(original_images)
        global_D_neg=global_discriminator(generated_images)
        
        local_D_pos=local_discriminator(original_images,localD_mask)
        local_D_neg=local_discriminator(generated_images,localD_mask)
        
        interp=getInterpSample(original_images,generated_images)
        global_D_interp=global_discriminator(interp)
        local_D_interp=local_discriminator(interp,localD_mask)
        penalty_local,penalty_global=getGradientPenalty(local_D_interp,global_D_interp,interp,images_mask)
        
        local_discriminator_loss=tf.reduce_mean(local_D_neg)-tf.reduce_mean(local_D_pos)+10*penalty_local
        global_discriminator_loss=tf.reduce_mean(global_D_neg)-tf.reduce_mean(global_D_pos)+10*penalty_global
        mse_generator_loss=tf.reduce_sum((generated_images-original_images)**2)/(self.batch_size*128*128*3)
        
        D_loss=10*local_discriminator_loss+global_discriminator_loss
        G_loss=-10*tf.reduce_mean(local_D_neg)-tf.reduce_mean(global_D_neg)+10*mse_generator_loss
        
        return D_loss,G_loss,generated_images
    
    def network_visualization(self):
        tensorboard_dir='tensorboard/'
        if not os.path.exists(tensorboard_dir):
            os.mkdir(tensorboard_dir)
        writer=tf.summary.FileWriter(tensorboard_dir)
        sess=tf.Session()
        sess.run(tf.global_variables_initializer())
        writer.add_graph(sess.graph)
        sess.close()
        
    def train(self):
        
        D_loss,G_loss,generated_images=self.build_net_architecture()
        
        graph=tf.get_default_graph()
        original_images=graph.get_tensor_by_name("original_images:0")
        images_mask=graph.get_tensor_by_name("images_mask:0")
        localD_mask=graph.get_tensor_by_name("localD_mask:0")
        
        

        #define optimizers
        t_vars=tf.trainable_variables()
        d_vars=[var for var in t_vars if 'discriminator' in var.name]
        g_vars=[var for var in t_vars if 'generator' in var.name]
        
        d_opt=tf.train.RMSPropOptimizer(learning_rate=1e-4).minimize(D_loss,var_list=d_vars)
        g_opt=tf.train.RMSPropOptimizer(learning_rate=1e-1).minimize(G_loss,var_list=g_vars)
        
        #training
        saver = tf.train.Saver()
        if not os.path.exists('checkpoints/'):
            os.makedirs('checkpoints/')
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            
            #saver.restore(sess, "checkpoints/model.ckpt")
            
            if not os.path.exists('out/'):
                os.makedirs('out/')
            
            for epoch in range(self.total_epoches):
                imgs_epoch=self.data.getEpochData(self.N_each_epoch)
                total_batch=int(self.N_each_epoch/self.batch_size)
                print("#########Training the %s epoch, the total_batch size is %s###########"%(epoch,total_batch))
                for e in range(total_batch):
                    print("Epoch: %d, batch: %d###" % (epoch,e),end=", ")
                    imgs=imgs_epoch[e*self.batch_size:min((e+1)*self.batch_size,self.N_each_epoch)]
                    mask_gen,mask_local=tsop.getMask_256(imgs)
                    
                    print("Training discriminators")
                    
                    _,D_loss_=sess.run([d_opt,D_loss],
                                            feed_dict={original_images:imgs,images_mask:mask_gen,localD_mask:mask_local})
                    
                    
                    print("After training dicriminators, the D_loss is %s"%D_loss_)
                    #i=0
                    #while(1):
                    #    i+=1
                    for i in range(10):
                        print("%d Training generator"%i,end=": ")
                        _,G_loss_,D_loss_=sess.run([g_opt,G_loss,D_loss],
                                       feed_dict={original_images:imgs,images_mask:mask_gen,localD_mask:mask_local})
                        print("In the generator training process, the D_loss is %s"%D_loss_)
                        #if abs(D_loss_)<0.1: break
                    print('---Epoch %s, D_loss: %s, G_loss: %s' % (epoch,D_loss_,G_loss_))    
                    
                #visulization
                    if e % 1 ==0:
                        img_out_t=sess.run(generated_images,feed_dict={original_images:imgs,
                                                                       images_mask:mask_gen,
                                                                       localD_mask:mask_local})
                        img_=img_out_t[0]
                        imsave('out/generated_%s.png' %(e),img_)
                        imsave('out/original_%s.png' %(e),imgs[0])
                        saver.save(sess, "checkpoints/model.ckpt")
            print("Done!")

# %%
gan=GAN()

# %%
gan.train()
# Out:
# Reading Image Bank size: 960
# Read Image Bank: (960, 256, 256, 3)
# #########Training the 0 epoch, the total_batch size is 30###########
# Epoch: 0, batch: 0###, Training discriminators
# After training dicriminators, the D_loss is 0.254839
# 0 Training generator: In the generator training process, the D_loss is 0.047804635
# 1 Training generator: In the generator training process, the D_loss is 0.04822952
# 2 Training generator: In the generator training process, the D_loss is 0.048856895
# 3 Training generator: In the generator training process, the D_loss is 0.04952847
# 4 Training generator: In the generator training process, the D_loss is 0.05021506
# 5 Training generator: In the generator training process, the D_loss is 0.050906476
# 6 Training generator: In the generator training process, the D_loss is 0.051713996
# 7 Training generator: In the generator training process, the D_loss is 0.05269253
# 8 Training generator: In the generator training process, the D_loss is 0.053366013
# 9 Training generator: In the generator training process, the D_loss is 0.05378167
# ---Epoch 0, D_loss: 0.05378167, G_loss: 0.90456367
# Epoch: 0, batch: 1###, Training discriminators
# After training dicriminators, the D_loss is 0.030743856
# 0 Training generator: In the generator training process, the D_loss is -0.14349315
# 1 Training generator: In the generator training process, the D_loss is -0.13236596
# 2 Training generator: In the generator training process, the D_loss is -0.11887334
# 3 Training generator: In the generator training process, the D_loss is -0.10382793
# 4 Training generator: In the generator training process, the D_loss is -0.09175135
# 5 Training generator: In the generator training process, the D_loss is -0.08590693
# 6 Training generator: In the generator training process, the D_loss is -0.08363158
# 7 Training generator: In the generator training process, the D_loss is -0.08657268
# 8 Training generator: In the generator training process, the D_loss is -0.082498014
# 9 Training generator: In the generator training process, the D_loss is -0.082524754
# ---Epoch 0, D_loss: -0.082524754, G_loss: 0.7518119
# Epoch: 0, batch: 2###, Training discriminators
# After training dicriminators, the D_loss is -0.077480026
# 0 Training generator: In the generator training process, the D_loss is -0.26076752
# 1 Training generator: In the generator training process, the D_loss is -0.31145766
# 2 Training generator: In the generator training process, the D_loss is -0.30976096
# 3 Training generator: In the generator training process, the D_loss is -0.30830836
# 4 Training generator: In the generator training process, the D_loss is -0.30673084
# 5 Training generator: In the generator training process, the D_loss is -0.30422023
# 6 Training generator: In the generator training process, the D_loss is -0.30071178
# 7 Training generator: In the generator training process, the D_loss is -0.29808405
# 8 Training generator: In the generator training process, the D_loss is -0.29554108
# 9 Training generator: In the generator training process, the D_loss is -0.29543218
# ---Epoch 0, D_loss: -0.29543218, G_loss: 1.036348
# Epoch: 0, batch: 3###, Training discriminators
# After training dicriminators, the D_loss is -0.3273578
# 0 Training generator: In the generator training process, the D_loss is -0.5634374
# 1 Training generator: In the generator training process, the D_loss is -0.5673288
# 2 Training generator: In the generator training process, the D_loss is -0.5670061
# 3 Training generator: In the generator training process, the D_loss is -0.5654711
# 4 Training generator: In the generator training process, the D_loss is -0.563621
# 5 Training generator: In the generator training process, the D_loss is -0.56183946
# 6 Training generator: In the generator training process, the D_loss is -0.56040424
# 7 Training generator: In the generator training process, the D_loss is -0.55783004
# 8 Training generator: In the generator training process, the D_loss is -0.55547476
# 9 Training generator: In the generator training process, the D_loss is -0.55357647
# ---Epoch 0, D_loss: -0.55357647, G_loss: 1.0302699
# Epoch: 0, batch: 4###, Training discriminators
# After training dicriminators, the D_loss is -0.5529873
# 0 Training generator: In the generator training process, the D_loss is -0.75756794
# 1 Training generator: In the generator training process, the D_loss is -0.5984223
# 2 Training generator: In the generator training process, the D_loss is -0.7110634
# 3 Training generator: In the generator training process, the D_loss is -0.6093517
# 4 Training generator: In the generator training process, the D_loss is -0.6619265
# 5 Training generator: In the generator training process, the D_loss is -0.5766591
# 6 Training generator: In the generator training process, the D_loss is -0.66775095
# 7 Training generator: In the generator training process, the D_loss is -0.5404103
# 8 Training generator: In the generator training process, the D_loss is -0.5694965
# 9 Training generator: In the generator training process, the D_loss is -0.6103439
# ---Epoch 0, D_loss: -0.6103439, G_loss: 0.9948734
# Epoch: 0, batch: 5###, Training discriminators
# After training dicriminators, the D_loss is -0.6173886
# 0 Training generator: In the generator training process, the D_loss is -0.78964984
# 1 Training generator: In the generator training process, the D_loss is -0.7163303
# 2 Training generator: In the generator training process, the D_loss is -0.6941281
# 3 Training generator: In the generator training process, the D_loss is -0.68559825
# 4 Training generator: In the generator training process, the D_loss is -0.67327833
# 5 Training generator: In the generator training process, the D_loss is -0.69469774
# 6 Training generator: In the generator training process, the D_loss is -0.5507235
# 7 Training generator: In the generator training process, the D_loss is -0.7440939
# 8 Training generator: In the generator training process, the D_loss is -0.43783382
# 9 Training generator: In the generator training process, the D_loss is -1.2743175
# ---Epoch 0, D_loss: -1.2743175, G_loss: 4.3090386
# Epoch: 0, batch: 6###, Training discriminators
# After training dicriminators, the D_loss is -0.99603444
# 0 Training generator: In the generator training process, the D_loss is -1.4791359
# 1 Training generator: In the generator training process, the D_loss is -1.0330427
# 2 Training generator: In the generator training process, the D_loss is -1.0330427
# 3 Training generator: In the generator training process, the D_loss is -1.0330427
# 4 Training generator: In the generator training process, the D_loss is -1.0330427
# 5 Training generator: In the generator training process, the D_loss is -1.0330427
# 6 Training generator: In the generator training process, the D_loss is -1.0330427
# 7 Training generator: In the generator training process, the D_loss is -1.0330427
# 8 Training generator: In the generator training process, the D_loss is -1.0330427
# 9 Training generator: In the generator training process, the D_loss is -1.0330427
# ---Epoch 0, D_loss: -1.0330427, G_loss: 3.5551102
# Epoch: 0, batch: 7###, Training discriminators
# After training dicriminators, the D_loss is -0.96379244
# 0 Training generator: In the generator training process, the D_loss is -1.4288735
# 1 Training generator: In the generator training process, the D_loss is -1.4288735
# 2 Training generator: In the generator training process, the D_loss is -1.4288735
# 3 Training generator: In the generator training process, the D_loss is -1.4288735
# 4 Training generator: In the generator training process, the D_loss is -1.4288735
# 5 Training generator: In the generator training process, the D_loss is -1.4288735
# 6 Training generator: In the generator training process, the D_loss is -1.4288735
# 7 Training generator: In the generator training process, the D_loss is -1.4288735
# 8 Training generator: In the generator training process, the D_loss is -1.4288735
# 9 Training generator: In the generator training process, the D_loss is -1.4288735
# ---Epoch 0, D_loss: -1.4288735, G_loss: 3.8435147
# Epoch: 0, batch: 8###, Training discriminators
# After training dicriminators, the D_loss is -1.5941712
# 0 Training generator: In the generator training process, the D_loss is -2.16251
# 1 Training generator: In the generator training process, the D_loss is -2.16251
# 2 Training generator: In the generator training process, the D_loss is -2.16251
# 3 Training generator: In the generator training process, the D_loss is -2.16251
# 4 Training generator: In the generator training process, the D_loss is -2.16251
# 5 Training generator: In the generator training process, the D_loss is -2.16251
# 6 Training generator: In the generator training process, the D_loss is -2.16251
# 7 Training generator: In the generator training process, the D_loss is -2.16251
# 8 Training generator: In the generator training process, the D_loss is -2.16251
# 9 Training generator: In the generator training process, the D_loss is -2.16251
# ---Epoch 0, D_loss: -2.16251, G_loss: 4.809274
# Epoch: 0, batch: 9###, Training discriminators
# After training dicriminators, the D_loss is -2.0115635
# 0 Training generator: In the generator training process, the D_loss is -2.542076
# 1 Training generator: In the generator training process, the D_loss is -2.542076
# 2 Training generator: In the generator training process, the D_loss is -2.542076
# 3 Training generator: In the generator training process, the D_loss is -2.542076
# 4 Training generator: In the generator training process, the D_loss is -2.542076
# 5 Training generator: In the generator training process, the D_loss is -2.542076
# 6 Training generator: In the generator training process, the D_loss is -2.542076
# 7 Training generator: In the generator training process, the D_loss is -2.542076
# 8 Training generator: In the generator training process, the D_loss is -2.542076
# 9 Training generator: In the generator training process, the D_loss is -2.542076
# ---Epoch 0, D_loss: -2.542076, G_loss: 4.3325524
# Epoch: 0, batch: 10###, Training discriminators
# After training dicriminators, the D_loss is -2.4708133
# 0 Training generator: In the generator training process, the D_loss is -3.0358505
# 1 Training generator: In the generator training process, the D_loss is -3.0358505
# 2 Training generator: In the generator training process, the D_loss is -3.0358505
# 3 Training generator: In the generator training process, the D_loss is -3.0358505
# 4 Training generator: In the generator training process, the D_loss is -3.0358505
# 5 Training generator: In the generator training process, the D_loss is -3.0358505
# 6 Training generator: In the generator training process, the D_loss is -3.0358505
# 7 Training generator: In the generator training process, the D_loss is -3.0358505
# 8 Training generator: In the generator training process, the D_loss is -3.0358505
# 9 Training generator: In the generator training process, the D_loss is -3.0358505
# ---Epoch 0, D_loss: -3.0358505, G_loss: 4.8546643
# Epoch: 0, batch: 11###, Training discriminators
# After training dicriminators, the D_loss is -3.0269363
# 0 Training generator: In the generator training process, the D_loss is -3.6924002
# 1 Training generator: In the generator training process, the D_loss is -3.6924002
# 2 Training generator: In the generator training process, the D_loss is -3.6924002
# 3 Training generator: In the generator training process, the D_loss is -3.6924002
# 4 Training generator: In the generator training process, the D_loss is -3.6924002
# 5 Training generator: In the generator training process, the D_loss is -3.6924002
# 6 Training generator: In the generator training process, the D_loss is -3.6924002
# 7 Training generator: In the generator training process, the D_loss is -3.6924002
# 8 Training generator: In the generator training process, the D_loss is -3.6924002
# 9 Training generator: In the generator training process, the D_loss is -3.6924002
# ---Epoch 0, D_loss: -3.6924002, G_loss: 5.3477583
# Epoch: 0, batch: 12###, Training discriminators
# After training dicriminators, the D_loss is -3.7753541
# 0 Training generator: In the generator training process, the D_loss is -4.609338
# 1 Training generator: In the generator training process, the D_loss is -4.609338
# 2 Training generator: In the generator training process, the D_loss is -4.609338
# 3 Training generator: In the generator training process, the D_loss is -4.609338
# 4 Training generator: In the generator training process, the D_loss is -4.609338
# 5 Training generator: In the generator training process, the D_loss is -4.609338
# 6 Training generator: In the generator training process, the D_loss is -4.609338
# 7 Training generator: In the generator training process, the D_loss is -4.609338
# 8 Training generator: In the generator training process, the D_loss is -4.609338
# 9 Training generator: In the generator training process, the D_loss is -4.609338
# ---Epoch 0, D_loss: -4.609338, G_loss: 6.1121917
# Epoch: 0, batch: 13###, Training discriminators
# After training dicriminators, the D_loss is -4.3900495
# 0 Training generator: In the generator training process, the D_loss is -5.3657155
# 1 Training generator: In the generator training process, the D_loss is -5.3657155
# 2 Training generator: In the generator training process, the D_loss is -5.3657155
# 3 Training generator: In the generator training process, the D_loss is -5.3657155
# 4 Training generator: In the generator training process, the D_loss is -5.3657155
# 5 Training generator: In the generator training process, the D_loss is -5.3657155
# 6 Training generator: In the generator training process, the D_loss is -5.3657155
# 7 Training generator: In the generator training process, the D_loss is -5.3657155
# 8 Training generator: In the generator training process, the D_loss is -5.3657155
# 9 Training generator: In the generator training process, the D_loss is -5.3657155
# ---Epoch 0, D_loss: -5.3657155, G_loss: 6.7266264
# Epoch: 0, batch: 14###, Training discriminators
# After training dicriminators, the D_loss is -5.4601316
# 0 Training generator: In the generator training process, the D_loss is -6.7607675
# 1 Training generator: In the generator training process, the D_loss is -6.7607675
# 2 Training generator: In the generator training process, the D_loss is -6.7607675
# 3 Training generator: In the generator training process, the D_loss is -6.7607675
# 4 Training generator: In the generator training process, the D_loss is -6.7607675
# 5 Training generator: In the generator training process, the D_loss is -6.7607675
# 6 Training generator: In the generator training process, the D_loss is -6.7607675
# 7 Training generator: In the generator training process, the D_loss is -6.7607675
# 8 Training generator: In the generator training process, the D_loss is -6.7607675
# 9 Training generator: In the generator training process, the D_loss is -6.7607675
# ---Epoch 0, D_loss: -6.7607675, G_loss: 7.7461367
# Epoch: 0, batch: 15###, Training discriminators
# After training dicriminators, the D_loss is -6.589798
# 0 Training generator: In the generator training process, the D_loss is -8.288302
# 1 Training generator: In the generator training process, the D_loss is -8.288302
# 2 Training generator: In the generator training process, the D_loss is -8.288302
# 3 Training generator: In the generator training process, the D_loss is -8.288302
# 4 Training generator: In the generator training process, the D_loss is -8.288302
# 5 Training generator: In the generator training process, the D_loss is -8.288302
# 6 Training generator: In the generator training process, the D_loss is -8.288302
# 7 Training generator: In the generator training process, the D_loss is -8.288302
# 8 Training generator: In the generator training process, the D_loss is -8.288302
# 9 Training generator: In the generator training process, the D_loss is -8.288302
# ---Epoch 0, D_loss: -8.288302, G_loss: 9.042135
# Epoch: 0, batch: 16###, Training discriminators
# After training dicriminators, the D_loss is -8.725016
# 0 Training generator: In the generator training process, the D_loss is -11.256074
# 1 Training generator: In the generator training process, the D_loss is -11.256074
# 2 Training generator: In the generator training process, the D_loss is -11.256074
# 3 Training generator: In the generator training process, the D_loss is -11.256074
# 4 Training generator: In the generator training process, the D_loss is -11.256074
# 5 Training generator: In the generator training process, the D_loss is -11.256074
# 6 Training generator: In the generator training process, the D_loss is -11.256074
# 7 Training generator: In the generator training process, the D_loss is -11.256074
# 8 Training generator: In the generator training process, the D_loss is -11.256074
# 9 Training generator: In the generator training process, the D_loss is -11.256074
# ---Epoch 0, D_loss: -11.256074, G_loss: 11.50253
# Epoch: 0, batch: 17###, Training discriminators
# After training dicriminators, the D_loss is -11.419057
# 0 Training generator: In the generator training process, the D_loss is -15.209392
# 1 Training generator: In the generator training process, the D_loss is -15.209392
# 2 Training generator: In the generator training process, the D_loss is -15.209392
# 3 Training generator: In the generator training process, the D_loss is -15.209392
# 4 Training generator: In the generator training process, the D_loss is -15.209392
# 5 Training generator: In the generator training process, the D_loss is -15.209392
# 6 Training generator: In the generator training process, the D_loss is -15.209392
# 7 Training generator: In the generator training process, the D_loss is -15.209392
# 8 Training generator: In the generator training process, the D_loss is -15.209392
# 9 Training generator: In the generator training process, the D_loss is -15.209392
# ---Epoch 0, D_loss: -15.209392, G_loss: 14.862094
# Epoch: 0, batch: 18###, Training discriminators
# After training dicriminators, the D_loss is -15.240461
# 0 Training generator: In the generator training process, the D_loss is -21.185783
# 1 Training generator: In the generator training process, the D_loss is -21.185783
# 2 Training generator: In the generator training process, the D_loss is -21.185783
# 3 Training generator: In the generator training process, the D_loss is -21.185783
# 4 Training generator: In the generator training process, the D_loss is -21.185783
# 5 Training generator: In the generator training process, the D_loss is -21.185783
# 6 Training generator: In the generator training process, the D_loss is -21.185783
# 7 Training generator: In the generator training process, the D_loss is -21.185783
# 8 Training generator: In the generator training process, the D_loss is -21.185783
# 9 Training generator: In the generator training process, the D_loss is -21.185783
# ---Epoch 0, D_loss: -21.185783, G_loss: 19.886139
# Epoch: 0, batch: 19###, Training discriminators
# After training dicriminators, the D_loss is -20.935898
# 0 Training generator: In the generator training process, the D_loss is -30.572258
# 1 Training generator: In the generator training process, the D_loss is -30.572258
# 2 Training generator: In the generator training process, the D_loss is -30.572258
# 3 Training generator: In the generator training process, the D_loss is -30.572258
# 4 Training generator: In the generator training process, the D_loss is -30.572258
# 5 Training generator: In the generator training process, the D_loss is -30.572258
# 6 Training generator: In the generator training process, the D_loss is -30.572258
# 7 Training generator: In the generator training process, the D_loss is -30.572258
# 8 Training generator: In the generator training process, the D_loss is -30.572258
# 9 Training generator: In the generator training process, the D_loss is -30.572258
# ---Epoch 0, D_loss: -30.572258, G_loss: 28.322842
# Epoch: 0, batch: 20###, Training discriminators
# After training dicriminators, the D_loss is -29.909641
# 0 Training generator: In the generator training process, the D_loss is -46.55402
# 1 Training generator: In the generator training process, the D_loss is -46.55402
# 2 Training generator: In the generator training process, the D_loss is -46.55402
# 3 Training generator: In the generator training process, the D_loss is -46.55402
# 4 Training generator: In the generator training process, the D_loss is -46.55402
# 5 Training generator: In the generator training process, the D_loss is -46.55402
# 6 Training generator: In the generator training process, the D_loss is -46.55402
# 7 Training generator: In the generator training process, the D_loss is -46.55402
# 8 Training generator: In the generator training process, the D_loss is -46.55402
# 9 Training generator: In the generator training process, the D_loss is -46.55402
# ---Epoch 0, D_loss: -46.55402, G_loss: 43.334156
# Epoch: 0, batch: 21###, Training discriminators
# After training dicriminators, the D_loss is -46.19922
# 0 Training generator: In the generator training process, the D_loss is -78.00899
# 1 Training generator: In the generator training process, the D_loss is -78.00899
# 2 Training generator: In the generator training process, the D_loss is -78.00899
# 3 Training generator: In the generator training process, the D_loss is -78.00899
# 4 Training generator: In the generator training process, the D_loss is -78.00899
# 5 Training generator: In the generator training process, the D_loss is -78.00899
# 6 Training generator: In the generator training process, the D_loss is -78.00899
# 7 Training generator: In the generator training process, the D_loss is -78.00899
# 8 Training generator: In the generator training process, the D_loss is -78.00899
# 9 Training generator: In the generator training process, the D_loss is -78.00899
# ---Epoch 0, D_loss: -78.00899, G_loss: 73.17299
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-8827ae40166e> in <module>()
# ----> 1 gan.train()
#
# <ipython-input-27-42956bd88e33> in train(self)
#     112                         imsave('out/generated_%s.png' %(e),img_)
#     113                         imsave('out/original_%s.png' %(e),imgs[0])
# --> 114                         saver.save(sess, "checkpoints/model.ckpt")
#     115             print("Done!")
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1175           model_checkpoint_path = sess.run(
#    1176               self.saver_def.save_tensor_name,
# -> 1177               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1178
#    1179         model_checkpoint_path = compat.as_str(model_checkpoint_path)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
gan.network_visualization()
